# %%
1.Data Sourcing

# %% [markdown]
# # Lending Club Case study

# %% [markdown]
# # Data sourcing
# loading data from loan_dataset

# %%
# import numpy as np
import pandas as pd

loan_data=pd.read_csv(r'C:\Users\lenovo\Desktop\python_codes_intro\loan_dataset.csv') 
print('Type of Data :',type(data))  #it created DataFrame to loan_dataset.csv
print(loan_data)
# getting pandas dataframe <class 'pandas.core.frame.DataFrame'>
#displaying Data
# Loan Data loaded with the help of Pandas library
# Data set used is the dataset provided in Data Understanding section  of case study of our program
# Out:
# Type of Data : <class 'pandas.core.frame.DataFrame'>
#             id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  \
# 0      1077501    1296599       5000         5000           4975.0
# 1      1077430    1314167       2500         2500           2500.0
# 2      1077175    1313524       2400         2400           2400.0
# 3      1076863    1277178      10000        10000          10000.0
# 4      1075358    1311748       3000         3000           3000.0
# ...        ...        ...        ...          ...              ...
# 39712    92187      92174       2500         2500           1075.0
# 39713    90665      90607       8500         8500            875.0
# 39714    90395      90390       5000         5000           1325.0
# 39715    90376      89243       5000         5000            650.0
# 39716    87023      86999       7500         7500            800.0
#
#              term int_rate  installment grade sub_grade  ...  \
# ...

# %%
print(data.shape)
#no of rows and columns of loaded dataset
we have 39717 rows and 111 columns
# Out:
# (39717, 111)

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# # Fix rows and columns

# %%
#checking for NaN value
import numpy as np
import pandas as pd
Na_Data=data.isna() # it returns True if value isNaN else False
# data having NaN values,all NaN data is replaced with True,else False
print(Na_Data,'Nan values are replaced with true')
# remove Not-verifed applicants from Data 
Na_Data.drop(Na_Data[['verification_status']]=='Not Verified',axis=1) 
#  list of verified Applicants
print(Na_Data ,'verified Applicants')
# number of verified applicants: 
print(Na_Data.shape)
#[39717 rows x 111 columns] verified Applicants
emptyvalues=Na_Data.drpna(axis=1,how=any)
print(emptyvalues.shape)
print(emptyvalues,'empty values removed')

# check still empty values in dataframe exist or not
# if empty values exist it will return true
# Out:
#           id  member_id  loan_amnt  funded_amnt  funded_amnt_inv   term  \
# 0      False      False      False        False            False  False
# 1      False      False      False        False            False  False
# 2      False      False      False        False            False  False
# 3      False      False      False        False            False  False
# 4      False      False      False        False            False  False
# ...      ...        ...        ...          ...              ...    ...
# 39712  False      False      False        False            False  False
# 39713  False      False      False        False            False  False
# 39714  False      False      False        False            False  False
# 39715  False      False      False        False            False  False
# 39716  False      False      False        False            False  False
#
#        int_rate  installment  grade  sub_grade  ...  num_tl_90g_dpd_24m  \
# ...

# %%
# Columns delete :All NA values

# CleanData=data.drop(['funded_amnt_inv','total_bc_limit','total_il_high_credit_limit','pct_tl_nvr_dlq','percent_bc_gt_75','num_tl_90g_dpd_24m', 'num_tl_op_past_12m', 'pct_tl_nvr_dlq'],axis=1)



# print(Not_verified_Users[['verification_status']],'Not_verified_Users')
# applicants=verified_Users[['verification_status']]==False
# print(verified_Users,'verified_Users')
# verified_applicants=applicants.drop(applicants[['verification_status']]==False,axis=1)
# print(verified_applicants,'verified_applicants')
# print(applicants,'applicants')
# print(verified,'verified data')
 
#verified contains verification_status=True,means they are verified applicants

# applicants=verified[:,verified[['verification_status']]]

# print(verified,'verified')
# print(applicants,'applicants')


# verified_Applicants=data.drop(['verification_status'!= 'Not Verified'],axis=0)
# print(verified_Applicants,'verified Applicants')

# conclusion giving loan to people who has not verified status can cause of loss
